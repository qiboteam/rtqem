# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
parton = 'u'
data = np.loadtxt(f'data/{parton}.dat')

# %%
plt.figure(figsize=(6,4))
plt.title(f'{parton} density function')
plt.plot(data.T[0], data.T[1], c='purple', alpha=0.65, lw=2)
plt.ylim(0,1)
plt.xscale('log')
plt.xlabel('x')
plt.ylabel('PDF')
# Out:
# Text(0, 0.5, 'PDF')
